# %%
import threading
import time

# Function 1
def function_1():
    while True:
        print("Function 1 is running")
        time.sleep(1)  # Simulate some work

# Function 2
def function_2():
    while True:
        print("Function 2 is running")
        time.sleep(1)  # Simulate some work

# Create and start the threads
thread1 = threading.Thread(target=function_1)
thread2 = threading.Thread(target=function_2)

thread1.start()
thread2.start()

# Keep the main thread running to allow the other threads to continue execution
while True:
    pass
# Out:
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is runningFunction 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is runningFunction 1 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 2 is runningFunction 1 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is runningFunction 1 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is runningFunction 1 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 2 is runningFunction 1 is running
#
# Function 2 is running
# Function 1 is running
# Function 1 is runningFunction 2 is running
# Function 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is runningFunction 2 is running
#
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is runningFunction 1 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
# Function 1 is running
# Function 2 is running
#
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is runningFunction 2 is running
#
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is runningFunction 1 is running
#
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is runningFunction 2 is running
#
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is runningFunction 1 is running
# Function 2 is running
#
# Function 1 is running
# Function 1 is runningFunction 2 is running
# Function 1 is running
#
# Function 2 is running
# Function 2 is runningFunction 1 is running
# Function 1 is running
# Function 2 is running
#
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 1 is running
#
# Function 2 is running
# Function 2 is running
# Function 1 is runningFunction 1 is running
#
# Function 2 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
# Function 1 is running
#
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 1 is runningFunction 2 is running
#
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
# Function 2 is running
# Function 1 is running
# Function 1 is running
# Function 2 is running
# Function 1 is running
# Function 2 is running
